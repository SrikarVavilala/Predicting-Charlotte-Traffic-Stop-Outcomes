# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.impute import KNNImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
stops = pd.read_csv("Officer_Traffic_Stops (1).csv")
stops2 = pd.read_csv("Officer_Traffic_Stops_2016-17.csv")

# %%
stops.head()
# Out:
#    OBJECTID Month_of_Stop            Reason_for_Stop     Officer_Race  \
# 0         1       2020/01  Speeding                             White
# 1         2       2021/05  Vehicle Equipment          Hispanic/Latino
# 2         3       2021/12  Speeding                             White
# 3         4       2020/01  Vehicle Equipment                    White
# 4         5       2020/01  Speeding                             White
#
#   Officer_Gender  Officer_Years_of_Service Driver_Race Driver_Ethnicity  \
# 0           Male                        27       White     Non-Hispanic
# 1         Female                         3       Black     Non-Hispanic
# 2           Male                        16       Black     Non-Hispanic
# 3         Female                         4       Black     Non-Hispanic
# 4           Male                        25       Black     Non-Hispanic
#
#   Driver_Gender  Driver_Age Was_a_Search_Conducted   Result_of_Stop  \
# 0        Female          38                     No   Verbal Warning
# 1          Male          35                     No   Verbal Warning
# 2          Male          29                     No   Verbal Warning
# 3          Male          33                     No   Verbal Warning
# 4          Male          36                     No  Citation Issued
#
#               CMPD_Division                                GlobalID
# 0  University City Division  {00000000-0000-0000-0000-000000000000}
# 1       Providence Division  {00000000-0000-0000-0000-000000000000}
# 2  University City Division  {00000000-0000-0000-0000-000000000000}
# 3  University City Division  {00000000-0000-0000-0000-000000000000}
# 4     Steele Creek Division  {00000000-0000-0000-0000-000000000000}

# %%
stops = stops.drop(['OBJECTID','GlobalID'],1)
# Out:
# C:\Users\hrgra\AppData\Local\Temp\ipykernel_32836\3212402041.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   stops = stops.drop(['OBJECTID','GlobalID'],1)

# %%
stops2.head()
# Out:
#   Month_of_Stop            Reason_for_Stop Officer_Race Officer_Gender  \
# 0       2017/06  Vehicle Regulatory               White         Female
# 1       2017/06  Vehicle Regulatory               White           Male
# 2       2017/06  Stop Light/Sign                  White           Male
# 3       2017/06  Vehicle Equipment                White           Male
# 4       2017/06  Stop Light/Sign                  White           Male
#
#    Officer_Years_of_Service Driver_Race Driver_Ethnicity Driver_Gender  \
# 0                         3       Black     Non-Hispanic          Male
# 1                         2       Black     Non-Hispanic          Male
# 2                         5       Black     Non-Hispanic          Male
# 3                        10       White     Non-Hispanic          Male
# 4                         2       Black     Non-Hispanic        Female
#
#    Driver_Age Was_a_Search_Conducted  Result_of_Stop         CMPD_Division  \
# 0          23                     No  Verbal Warning  North Tryon Division
# 1          36                     No  Verbal Warning      Central Division
# 2          45                     No  Verbal Warning      Central Division
# 3          30                     No  Verbal Warning        South Division
# 4          37                     No  Verbal Warning      Central Division
#
#    ObjectID              CreationDate      Creator                  EditDate  \
# 0      3001  2019-02-16T10:01:44.227Z  CharlotteNC  2019-02-16T10:01:44.227Z
# 1      3002  2019-02-16T10:01:44.227Z  CharlotteNC  2019-02-16T10:01:44.227Z
# 2      3003  2019-02-16T10:01:44.227Z  CharlotteNC  2019-02-16T10:01:44.227Z
# 3      3004  2019-02-16T10:01:44.227Z  CharlotteNC  2019-02-16T10:01:44.227Z
# 4      3005  2019-02-16T10:01:44.227Z  CharlotteNC  2019-02-16T10:01:44.227Z
#
#         Editor
# 0  CharlotteNC
# 1  CharlotteNC
# 2  CharlotteNC
# 3  CharlotteNC
# 4  CharlotteNC

# %%
stops2 = stops2.drop(['ObjectID','CreationDate','Creator','EditDate','Editor'],1)
# Out:
# C:\Users\hrgra\AppData\Local\Temp\ipykernel_32836\467063336.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   stops2 = stops2.drop(['ObjectID','CreationDate','Creator','EditDate','Editor'],1)

# %%
stops = stops.append(stops2, ignore_index=True)

stops
# Out:
#        Month_of_Stop            Reason_for_Stop            Officer_Race  \
# 0            2020/01  Speeding                                    White
# 1            2021/05  Vehicle Equipment                 Hispanic/Latino
# 2            2021/12  Speeding                                    White
# 3            2020/01  Vehicle Equipment                           White
# 4            2020/01  Speeding                                    White
# ...              ...                        ...                     ...
# 208011       2017/06  Vehicle Regulatory                          White
# 208012       2017/06  Stop Light/Sign            Black/African American
# 208013       2017/06  Vehicle Regulatory                          White
# 208014       2017/06  Stop Light/Sign            Black/African American
# 208015       2017/06  Speeding                          Hispanic/Latino
#
#        Officer_Gender  Officer_Years_of_Service Driver_Race Driver_Ethnicity  \
# 0                Male                        27       White     Non-Hispanic
# 1              Female                         3       Black     Non-Hispanic
# 2                Male                        16       Black     Non-Hispanic
# 3              Female                         4       Black     Non-Hispanic
# 4                Male                        25       Black     Non-Hispanic
# ...               ...                       ...         ...              ...
# 208011         Female                        16       White     Non-Hispanic
# 208012           Male                         3       Black     Non-Hispanic
# 208013         Female                         2       Black     Non-Hispanic
# 208014           Male                         6       White     Non-Hispanic
# 208015           Male                        19       White         Hispanic
#
#        Driver_Gender  Driver_Age Was_a_Search_Conducted   Result_of_Stop  \
# 0             Female          38                     No   Verbal Warning
# 1               Male          35                     No   Verbal Warning
# 2               Male          29                     No   Verbal Warning
# 3               Male          33                     No   Verbal Warning
# 4               Male          36                     No  Citation Issued
# ...              ...         ...                    ...              ...
# 208011          Male          35                     No  Citation Issued
# 208012        Female          24                     No  Written Warning
# 208013          Male          20                     No  Written Warning
# 208014          Male          43                     No  Citation Issued
# 208015        Female          37                     No  Written Warning
#
#                    CMPD_Division
# 0       University City Division
# 1            Providence Division
# 2       University City Division
# 3       University City Division
# 4          Steele Creek Division
# ...                          ...
# 208011            South Division
# 208012            Metro Division
# 208013    Hickory Grove Division
# 208014     Independence Division
# 208015            South Division
#
# [208016 rows x 12 columns]

# %%
print(stops.isna().any())
print(stops.dtypes)
# Out:
# Month_of_Stop               False
# Reason_for_Stop             False
# Officer_Race                False
# Officer_Gender              False
# Officer_Years_of_Service    False
# Driver_Race                 False
# Driver_Ethnicity            False
# Driver_Gender               False
# Driver_Age                  False
# Was_a_Search_Conducted      False
# Result_of_Stop              False
# CMPD_Division                True
# dtype: bool
# Month_of_Stop               object
# Reason_for_Stop             object
# Officer_Race                object
# Officer_Gender              object
# Officer_Years_of_Service     int64
# Driver_Race                 object
# Driver_Ethnicity            object
# Driver_Gender               object
# Driver_Age                   int64
# Was_a_Search_Conducted      object
# Result_of_Stop              object
# CMPD_Division               object
# dtype: object

# %%
#Checking for any typo's during data entry. Potential variations of the same input.
#No typo's. 48 entries for each month of 2020-2021, and 2016-2017.

stops.Month_of_Stop.unique()
# Out:
# array(['2020/01', '2021/05', '2021/12', '2020/02', '2021/01', '2020/03',
#        '2020/09', '2020/05', '2021/02', '2020/04', '2020/07', '2021/04',
#        '2020/06', '2021/06', '2020/08', '2020/10', '2021/03', '2020/11',
#        '2020/12', '2021/08', '2021/09', '2021/07', '2021/10', '2021/11',
#        '2017/06', '2017/08', '2017/07', '2017/05', '2017/04', '2017/09',
#        '2017/12', '2017/11', '2017/10', '2016/02', '2017/02', '2016/01',
#        '2016/07', '2016/08', '2016/06', '2016/05', '2016/04', '2016/10',
#        '2016/09', '2016/11', '2016/12', '2016/03', '2017/01', '2017/03'],
#       dtype=object)

# %%
# convert the 'Date' column to datetime format
import datetime as dt
isinstance(stops['Month_of_Stop'], dt.date) # False

stops['Month_of_Stop'] = stops['Month_of_Stop'].astype('datetime64[ns]')
stops['Month_of_Stop'] = pd.to_datetime(stops['Month_of_Stop'], format='%y%m%d')

# %%
#Checking for any typo's during data entry. Potential variations of the same input.
#No typo's found.

stops.Reason_for_Stop.unique()
# Out:
# array(['Speeding                 ', 'Vehicle Equipment        ',
#        'Vehicle Regulatory       ', 'Stop Light/Sign          ',
#        'Investigation            ', 'Safe Movement            ',
#        'Other                    ', 'Driving While Impaired   ',
#        'SeatBelt                 ', 'CheckPoint               '],
#       dtype=object)

# %%
#Checking for any typo's during data entry. Potential variations of the same input.
#No typo's found.

stops.Officer_Race.unique()
# Out:
# array(['White', 'Hispanic/Latino', 'Black/African American',
#        'Asian / Pacific Islander', '2 or More', 'Not Specified',
#        'American Indian/Alaska Native', ' ',
#        'Native Hawaiian/Oth Pac Island'], dtype=object)

# %%
#Checking for any typo's during data entry. Potential variations of the same input.
#No typo's found.

stops.Officer_Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
#Checking for any typo's during data entry. Potential variations of the same input.
#No typo's found.

stops.Officer_Years_of_Service.unique()
# Out:
# array([27,  3, 16,  4, 25,  5,  8, 13,  6,  2, 22,  7,  9, 17, 10, 18, 19,
#        12, 15,  1, 20, 11, 32, 26, 21, 23, 30, 14, 29, 24, 28, 39, 33, 31,
#        34, 35], dtype=int64)

# %%
#Checking for any typo's during data entry. Potential variations of the same input.
#No typo's found.
#Driver_Race options are not the same as Officer_Race options. Officers have 'Hispanic/Latino option, as well as a mixed race option.'

stops.Driver_Race.unique()
# Out:
# array(['White', 'Black', 'Other/Unknown', 'Asian', 'Native American'],
#       dtype=object)

# %%
#Checking for any typo's during data entry. Potential variations of the same input.
#No typo's found.

stops.Driver_Ethnicity.unique()
# Out:
# array(['Non-Hispanic', 'Hispanic'], dtype=object)

# %%
#Checking for any typo's during data entry. Potential variations of the same input.
#No typo's found.

stops.Driver_Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
#Checking for all ages
#Ages below 15 (earliest age eligible for driver's permit) are recorded. Typo or someone illegally driving underage? Ages 10-14 represented
#Keep in dataset or remove? 68 observations in this Driver_Age range

a = stops.Driver_Age.unique()
sorted(a)
stops[stops['Driver_Age']<15]
# Out:
#        Month_of_Stop            Reason_for_Stop            Officer_Race  \
# 10971     2020-02-01  Investigation                               White
# 12315     2020-02-01  Vehicle Equipment                           White
# 19529     2020-04-01  Safe Movement                               White
# 22791     2020-03-01  Other                      Black/African American
# 23506     2020-04-01  Other                                       White
# ...              ...                        ...                     ...
# 161222    2017-06-01  Stop Light/Sign                             White
# 173432    2016-02-01  Stop Light/Sign            Black/African American
# 180407    2016-11-01  Safe Movement              Black/African American
# 180794    2017-06-01  Safe Movement                               White
# 189089    2016-04-01  Safe Movement                               White
#
#        Officer_Gender  Officer_Years_of_Service    Driver_Race  \
# 10971            Male                         7          Black
# 12315          Female                         2  Other/Unknown
# 19529            Male                         6          Black
# 22791            Male                         1          Black
# 23506          Female                         1  Other/Unknown
# ...               ...                       ...            ...
# 161222           Male                         4          Black
# 173432           Male                         8          Black
# 180407         Female                         3          White
# 180794           Male                         8          Black
# 189089           Male                        20          Black
#
#        Driver_Ethnicity Driver_Gender  Driver_Age Was_a_Search_Conducted  \
# 10971      Non-Hispanic          Male          14                     No
# 12315      Non-Hispanic          Male          10                     No
# 19529      Non-Hispanic          Male          14                     No
# 22791      Non-Hispanic        Female          13                     No
# 23506      Non-Hispanic          Male          10                     No
# ...                 ...           ...         ...                    ...
# 161222     Non-Hispanic          Male          10                     No
# 173432     Non-Hispanic          Male          14                     No
# 180407         Hispanic          Male          14                     No
# 180794     Non-Hispanic          Male          13                    Yes
# 189089     Non-Hispanic          Male          10                     No
#
#          Result_of_Stop             CMPD_Division
# 10971   No Action Taken  University City Division
# 12315   No Action Taken            Metro Division
# 19529            Arrest  University City Division
# 22791            Arrest          Eastway Division
# 23506   No Action Taken            North Division
# ...                 ...                       ...
# 161222   Verbal Warning  University City Division
# 173432   Verbal Warning     Independence Division
# 180407  Citation Issued          Freedom Division
# 180794           Arrest            Metro Division
# 189089  Written Warning          Eastway Division
#
# [68 rows x 12 columns]

# %%
#reason for stop of drivers below drivers permit age
#reasons do not appear to be specifically related to age. Reasons are not exclusive to officer observing a young driver behind the wheel.
#Remove?
young = stops[stops["Driver_Age"] <15]
print(young.groupby('Reason_for_Stop').count())
print(young.groupby('Result_of_Stop').count())

stops = stops[stops["Driver_Age"]>14]
# Out:
#                            Month_of_Stop  Officer_Race  Officer_Gender  \
# Reason_for_Stop
# Investigation                          9             9               9
# Other                                 12            12              12
# Safe Movement                         15            15              15
# Speeding                               9             9               9
# Stop Light/Sign                        7             7               7
# Vehicle Equipment                      8             8               8
# Vehicle Regulatory                     8             8               8
#
#                            Officer_Years_of_Service  Driver_Race  \
# Reason_for_Stop
# Investigation                                     9            9
# Other                                            12           12
# Safe Movement                                    15           15
# Speeding                                          9            9
# Stop Light/Sign                                   7            7
# Vehicle Equipment                                 8            8
# Vehicle Regulatory                                8            8
#
#                            Driver_Ethnicity  Driver_Gender  Driver_Age  \
# Reason_for_Stop
# Investigation                             9              9           9
# Other                                    12             12          12
# Safe Movement                            15             15          15
# Speeding                                  9              9           9
# Stop Light/Sign                           7              7           7
# Vehicle Equipment                         8              8           8
# Vehicle Regulatory                        8              8           8
#
#                            Was_a_Search_Conducted  Result_of_Stop  \
# Reason_for_Stop
# Investigation                                   9               9
# Other                                          12              12
# Safe Movement                                  15              15
# Speeding                                        9               9
# Stop Light/Sign                                 7               7
# Vehicle Equipment                               8               8
# Vehicle Regulatory                              8               8
#
#                            CMPD_Division
# Reason_for_Stop
# Investigation                          9
# Other                                 12
# Safe Movement                         15
# Speeding                               8
# Stop Light/Sign                        7
# Vehicle Equipment                      8
# Vehicle Regulatory                     8
#                  Month_of_Stop  Reason_for_Stop  Officer_Race  Officer_Gender  \
# Result_of_Stop
# Arrest                      13               13            13              13
# Citation Issued              4                4             4               4
# No Action Taken             29               29            29              29
# Verbal Warning              21               21            21              21
# Written Warning              1                1             1               1
#
#                  Officer_Years_of_Service  Driver_Race  Driver_Ethnicity  \
# Result_of_Stop
# Arrest                                 13           13                13
# Citation Issued                         4            4                 4
# No Action Taken                        29           29                29
# Verbal Warning                         21           21                21
# Written Warning                         1            1                 1
#
#                  Driver_Gender  Driver_Age  Was_a_Search_Conducted  \
# Result_of_Stop
# Arrest                      13          13                      13
# Citation Issued              4           4                       4
# No Action Taken             29          29                      29
# Verbal Warning              21          21                      21
# Written Warning              1           1                       1
#
#                  CMPD_Division
# Result_of_Stop
# Arrest                      12
# Citation Issued              4
# No Action Taken             29
# Verbal Warning              21
# Written Warning              1

# %%
#Checking for any typo's during data entry. Potential variations of the same input.
#No typo's found.

stops.Was_a_Search_Conducted.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
#Checking for any typo's during data entry. Potential variations of the same input.
#No typo's found.

stops.Result_of_Stop.unique()
# Out:
# array(['Verbal Warning', 'Citation Issued', 'No Action Taken',
#        'Written Warning', 'Arrest'], dtype=object)

# %%
#Checking for any typo's during data entry. Potential variations of the same input.
#No typo's found.
#Contains NULL values. For location analysis should remove. For aggregate demographic analysis is helpful.
#Create 2nd version of the dataset??

print(stops.CMPD_Division.unique())
stops['CMPD_Division'].isna().sum()
# Out:
# ['University City Division' 'Providence Division' 'Steele Creek Division'
#  'Eastway Division' nan 'Hickory Grove Division' 'Westover Division'
#  'South Division' 'Central Division' 'North Tryon Division'
#  'Independence Division' 'Metro Division' 'North Division'
#  'Freedom Division']
# 4967

# %%
#Setting binary variables

from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
stops['Officer_Gender'] = label_encoder.fit_transform(stops['Officer_Gender']) #0 female, 1 male
stops['Driver_Ethnicity'] = label_encoder.fit_transform(stops['Driver_Ethnicity']) #0 Hispanic, 1 Non-Hispanic
stops['Driver_Gender'] = label_encoder.fit_transform(stops['Driver_Gender']) #0 female, 1 male
stops['Was_a_Search_Conducted'] = label_encoder.fit_transform(stops['Driver_Ethnicity']) # 0 yes, 1 no

stops
# Out:
# C:\Users\hrgra\AppData\Local\Temp\ipykernel_32836\147014699.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stops['Officer_Gender'] = label_encoder.fit_transform(stops['Officer_Gender']) #0 female, 1 male
# C:\Users\hrgra\AppData\Local\Temp\ipykernel_32836\147014699.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stops['Driver_Ethnicity'] = label_encoder.fit_transform(stops['Driver_Ethnicity']) #0 Hispanic, 1 Non-Hispanic
# C:\Users\hrgra\AppData\Local\Temp\ipykernel_32836\147014699.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stops['Driver_Gender'] = label_encoder.fit_transform(stops['Driver_Gender']) #0 female, 1 male
# C:\Users\hrgra\AppData\Local\Temp\ipykernel_32836\147014699.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stops['Was_a_Search_Conducted'] = label_encoder.fit_transform(stops['Driver_Ethnicity']) # 0 yes, 1 no
#        Month_of_Stop            Reason_for_Stop            Officer_Race  \
# 0         2020-01-01  Speeding                                    White
# 1         2021-05-01  Vehicle Equipment                 Hispanic/Latino
# 2         2021-12-01  Speeding                                    White
# 3         2020-01-01  Vehicle Equipment                           White
# 4         2020-01-01  Speeding                                    White
# ...              ...                        ...                     ...
# 208011    2017-06-01  Vehicle Regulatory                          White
# 208012    2017-06-01  Stop Light/Sign            Black/African American
# 208013    2017-06-01  Vehicle Regulatory                          White
# 208014    2017-06-01  Stop Light/Sign            Black/African American
# 208015    2017-06-01  Speeding                          Hispanic/Latino
#
#         Officer_Gender  Officer_Years_of_Service Driver_Race  \
# 0                    1                        27       White
# 1                    0                         3       Black
# 2                    1                        16       Black
# 3                    0                         4       Black
# 4                    1                        25       Black
# ...                ...                       ...         ...
# 208011               0                        16       White
# 208012               1                         3       Black
# 208013               0                         2       Black
# 208014               1                         6       White
# 208015               1                        19       White
#
#         Driver_Ethnicity  Driver_Gender  Driver_Age  Was_a_Search_Conducted  \
# 0                      1              0          38                       1
# 1                      1              1          35                       1
# 2                      1              1          29                       1
# 3                      1              1          33                       1
# 4                      1              1          36                       1
# ...                  ...            ...         ...                     ...
# 208011                 1              1          35                       1
# 208012                 1              0          24                       1
# 208013                 1              1          20                       1
# 208014                 1              1          43                       1
# 208015                 0              0          37                       0
#
#          Result_of_Stop             CMPD_Division
# 0        Verbal Warning  University City Division
# 1        Verbal Warning       Providence Division
# 2        Verbal Warning  University City Division
# 3        Verbal Warning  University City Division
# 4       Citation Issued     Steele Creek Division
# ...                 ...                       ...
# 208011  Citation Issued            South Division
# 208012  Written Warning            Metro Division
# 208013  Written Warning    Hickory Grove Division
# 208014  Citation Issued     Independence Division
# 208015  Written Warning            South Division
#
# [207948 rows x 12 columns]

# %%
# Grouping Result_of_Stop into fewer categories. Combing 'No Action Taken', 'Verbal Warning', and 'Written Warning'
stops['Outcome'] = pd.np.where(stops.Result_of_Stop.str.contains("Arrest"), "Arrest",
                   pd.np.where(stops.Result_of_Stop.str.contains("Citation Issued"), "Citation","Warning/No Action"))
stops
# Out:
# C:\Users\hrgra\AppData\Local\Temp\ipykernel_32836\968829713.py:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   stops['Outcome'] = pd.np.where(stops.Result_of_Stop.str.contains("Arrest"), "Arrest",
# C:\Users\hrgra\AppData\Local\Temp\ipykernel_32836\968829713.py:3: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(stops.Result_of_Stop.str.contains("Citation Issued"), "Citation","Warning/No Action"))
# C:\Users\hrgra\AppData\Local\Temp\ipykernel_32836\968829713.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stops['Outcome'] = pd.np.where(stops.Result_of_Stop.str.contains("Arrest"), "Arrest",
#        Month_of_Stop            Reason_for_Stop            Officer_Race  \
# 0         2020-01-01  Speeding                                    White
# 1         2021-05-01  Vehicle Equipment                 Hispanic/Latino
# 2         2021-12-01  Speeding                                    White
# 3         2020-01-01  Vehicle Equipment                           White
# 4         2020-01-01  Speeding                                    White
# ...              ...                        ...                     ...
# 208011    2017-06-01  Vehicle Regulatory                          White
# 208012    2017-06-01  Stop Light/Sign            Black/African American
# 208013    2017-06-01  Vehicle Regulatory                          White
# 208014    2017-06-01  Stop Light/Sign            Black/African American
# 208015    2017-06-01  Speeding                          Hispanic/Latino
#
#         Officer_Gender  Officer_Years_of_Service Driver_Race  \
# 0                    1                        27       White
# 1                    0                         3       Black
# 2                    1                        16       Black
# 3                    0                         4       Black
# 4                    1                        25       Black
# ...                ...                       ...         ...
# 208011               0                        16       White
# 208012               1                         3       Black
# 208013               0                         2       Black
# 208014               1                         6       White
# 208015               1                        19       White
#
#         Driver_Ethnicity  Driver_Gender  Driver_Age  Was_a_Search_Conducted  \
# 0                      1              0          38                       1
# 1                      1              1          35                       1
# 2                      1              1          29                       1
# 3                      1              1          33                       1
# 4                      1              1          36                       1
# ...                  ...            ...         ...                     ...
# 208011                 1              1          35                       1
# 208012                 1              0          24                       1
# 208013                 1              1          20                       1
# 208014                 1              1          43                       1
# 208015                 0              0          37                       0
#
#          Result_of_Stop             CMPD_Division            Outcome
# 0        Verbal Warning  University City Division  Warning/No Action
# 1        Verbal Warning       Providence Division  Warning/No Action
# 2        Verbal Warning  University City Division  Warning/No Action
# 3        Verbal Warning  University City Division  Warning/No Action
# 4       Citation Issued     Steele Creek Division           Citation
# ...                 ...                       ...                ...
# 208011  Citation Issued            South Division           Citation
# 208012  Written Warning            Metro Division  Warning/No Action
# 208013  Written Warning    Hickory Grove Division  Warning/No Action
# 208014  Citation Issued     Independence Division           Citation
# 208015  Written Warning            South Division  Warning/No Action
#
# [207948 rows x 13 columns]

# %%
# Grouping Officer_Race into same racial groupings as Driver_Age to be able to determine if they match

stops['temp'] = pd.np.where(stops.Officer_Race.str.contains("White"), "White",
                pd.np.where(stops.Officer_Race.str.contains("Black/African American"), "Black",
                pd.np.where(stops.Officer_Race.str.contains("Asian / Pacific Islander"), "Asian",
                pd.np.where(stops.Officer_Race.str.contains("American Indian/Alaska Native"),"Native American","Other/Unknown"))))

stops['Racial_Match'] = np.where(stops.Driver_Race == stops.temp,1,0)

stops = stops.drop(['temp'],1)

stops
# Out:
# C:\Users\hrgra\AppData\Local\Temp\ipykernel_32836\85585337.py:3: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   stops['temp'] = pd.np.where(stops.Officer_Race.str.contains("White"), "White",
# C:\Users\hrgra\AppData\Local\Temp\ipykernel_32836\85585337.py:4: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(stops.Officer_Race.str.contains("Black/African American"), "Black",
# C:\Users\hrgra\AppData\Local\Temp\ipykernel_32836\85585337.py:5: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(stops.Officer_Race.str.contains("Asian / Pacific Islander"), "Asian",
# C:\Users\hrgra\AppData\Local\Temp\ipykernel_32836\85585337.py:6: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.where(stops.Officer_Race.str.contains("American Indian/Alaska Native"),"Native American","Other/Unknown"))))
# C:\Users\hrgra\AppData\Local\Temp\ipykernel_32836\85585337.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stops['temp'] = pd.np.where(stops.Officer_Race.str.contains("White"), "White",
# C:\Users\hrgra\AppData\Local\Temp\ipykernel_32836\85585337.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stops['Racial_Match'] = np.where(stops.Driver_Race == stops.temp,1,0)
# C:\Users\hrgra\AppData\Local\Temp\ipykernel_32836\85585337.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   stops = stops.drop(['temp'],1)
#        Month_of_Stop            Reason_for_Stop            Officer_Race  \
# 0         2020-01-01  Speeding                                    White
# 1         2021-05-01  Vehicle Equipment                 Hispanic/Latino
# 2         2021-12-01  Speeding                                    White
# 3         2020-01-01  Vehicle Equipment                           White
# 4         2020-01-01  Speeding                                    White
# ...              ...                        ...                     ...
# 208011    2017-06-01  Vehicle Regulatory                          White
# 208012    2017-06-01  Stop Light/Sign            Black/African American
# 208013    2017-06-01  Vehicle Regulatory                          White
# 208014    2017-06-01  Stop Light/Sign            Black/African American
# 208015    2017-06-01  Speeding                          Hispanic/Latino
#
#         Officer_Gender  Officer_Years_of_Service Driver_Race  \
# 0                    1                        27       White
# 1                    0                         3       Black
# 2                    1                        16       Black
# 3                    0                         4       Black
# 4                    1                        25       Black
# ...                ...                       ...         ...
# 208011               0                        16       White
# 208012               1                         3       Black
# 208013               0                         2       Black
# 208014               1                         6       White
# 208015               1                        19       White
#
#         Driver_Ethnicity  Driver_Gender  Driver_Age  Was_a_Search_Conducted  \
# 0                      1              0          38                       1
# 1                      1              1          35                       1
# 2                      1              1          29                       1
# 3                      1              1          33                       1
# 4                      1              1          36                       1
# ...                  ...            ...         ...                     ...
# 208011                 1              1          35                       1
# 208012                 1              0          24                       1
# 208013                 1              1          20                       1
# 208014                 1              1          43                       1
# 208015                 0              0          37                       0
#
#          Result_of_Stop             CMPD_Division            Outcome  \
# 0        Verbal Warning  University City Division  Warning/No Action
# 1        Verbal Warning       Providence Division  Warning/No Action
# 2        Verbal Warning  University City Division  Warning/No Action
# 3        Verbal Warning  University City Division  Warning/No Action
# 4       Citation Issued     Steele Creek Division           Citation
# ...                 ...                       ...                ...
# 208011  Citation Issued            South Division           Citation
# 208012  Written Warning            Metro Division  Warning/No Action
# 208013  Written Warning    Hickory Grove Division  Warning/No Action
# 208014  Citation Issued     Independence Division           Citation
# 208015  Written Warning            South Division  Warning/No Action
#
#         Racial_Match
# 0                  1
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 208011             1
# 208012             1
# 208013             0
# 208014             0
# 208015             0
#
# [207948 rows x 14 columns]

# %%
# all years dataset, and separating 2016-2017 from 2020-2021

stops_all = stops

stops_2016 = stops[stops['Month_of_Stop'] < '2018-01-01']

stops_2020 = stops[stops['Month_of_Stop'] > '2018-01-01']

stops_all_trimmed = stops_all.dropna()

stops_2016_trimmed = stops_2016.dropna()

stops_2020_trimmed = stops_2020.dropna()

# %%
# export to csv. Versions with all stops, and separated by year grouping. 
# Then the same versions duplicated but with missing CMPD Division entries removed

# all
stops_all.to_csv('stops_all.csv')

# 2020-2021
stops_2020.to_csv('stops_2020.csv')

# 2016-2017
stops_2016.to_csv('stops_2016.csv')

# all with NAs removed
stops_all_trimmed.to_csv('stops_all_trimmed.csv')

# 2020-2021 with NAs removed
stops_2020_trimmed.to_csv('stops_2020_trimmed.csv')

# 2016-2017
stops_2016_trimmed.to_csv('stops_2016_trimmed.csv')
